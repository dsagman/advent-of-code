# %%
from transitions import Machine
import re

class Part:
    def __init__(self, ratings):
        self.ratings = ratings

class WorkflowMachine:
    def __init__(self, workflows):
        self.workflows = self.parse_workflows(workflows)
        self.machine = Machine(model=self, states=list(self.workflows.keys()), initial='in')
        self.add_transitions()

    def parse_workflows(self, workflows):
        workflow_dict = {}
        for workflow in workflows:
            name, rules_str = workflow.split('{')
            rules_str = rules_str[:-1]
            rules = rules_str.split(',')
            parsed_rules = []
            for rule in rules:
                condition, action = rule.split(':') if ':' in rule else (None, rule)
                parsed_rules.append((condition, action))
            workflow_dict[name] = parsed_rules
        return workflow_dict

    def add_transitions(self):
        for workflow, rules in self.workflows.items():
            for condition, action in rules:
                if condition:
                    self.machine.add_transition(
                        trigger='process',
                        source=workflow,
                        dest='=' + action,
                        conditions=lambda part, condition=condition: self.check_condition(part, condition)
                    )
                else:
                    self.machine.add_transition(
                        trigger='process',
                        source=workflow,
                        dest=action
                    )

    def check_condition(self, part, condition):
        match = re.match(r'([xmas])\s*([<>])\s*(\d+)', condition)
        if match:
            attr, operator, value = match.groups()
            part_value = part.ratings[attr]
            value = int(value)
            return (part_value > value if operator == '>' else part_value < value)
        return False

    def process_part(self, part):
        while self.state not in ['A', 'R']:
            self.process(part)
        return self.state

workflows = [
    'px{a<2006:qkq,m>2090:A,rfg}',
    'pv{a>1716:R,A}',
    'lnx{m>1548:A,A}',
    'rfg{s<537:gd,x>2440:R,A}',
    'qs{s>3448:A,lnx}',
    'qkq{x<1416:A,crn}',
    'crn{x>2662:A,R}',
    'in{s<1351:px,qqz}',
    'qqz{s>2770:qs,m<1801:hdj,R}',
    'gd{a>3333:R,R}',
    'hdj{m>838:A,pv}',
]

parts = [ 
    '{x=787,m=2655,a=1222,s=2876}', 
    '{x=1679,m=44,a=2067,s=496}',  
    '{x=2036,m=264,a=79,s=2244}',  
    '{x=2461,m=1339,a=466,s=291}', 
    '{x=2127,m=1623,a=2188,s=1013}' 
    ]

def parse_part(part_str):
    ratings = re.findall(r'([xmas])=(\d+)', part_str)
    return {k: int(v) for k, v in ratings}

# %%
machine = WorkflowMachine(workflows)
print(machine.state)
print(machine.workflows)
accepted_parts_sum = 0

for part_str in parts:
    part_ratings = parse_part(part_str)
    print(part_ratings)
    part = Part(part_ratings)
    print(part.ratings)
    result = machine.process_part(part)
    print(result)
    if result == 'A':
        accepted_parts_sum += sum(part_ratings.values())

print(accepted_parts_sum)
# Out:
# in
# {'px': [('a<2006', 'qkq'), ('m>2090', 'A'), (None, 'rfg')], 'pv': [('a>1716', 'R'), (None, 'A')], 'lnx': [('m>1548', 'A'), (None, 'A')], 'rfg': [('s<537', 'gd'), ('x>2440', 'R'), (None, 'A')], 'qs': [('s>3448', 'A'), (None, 'lnx')], 'qkq': [('x<1416', 'A'), (None, 'crn')], 'crn': [('x>2662', 'A'), (None, 'R')], 'in': [('s<1351', 'px'), (None, 'qqz')], 'qqz': [('s>2770', 'qs'), ('m<1801', 'hdj'), (None, 'R')], 'gd': [('a>3333', 'R'), (None, 'R')], 'hdj': [('m>838', 'A'), (None, 'pv')]}
# {'x': 787, 'm': 2655, 'a': 1222, 's': 2876}
# {'x': 787, 'm': 2655, 'a': 1222, 's': 2876}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 11
#       9 part = Part(part_ratings)
#      10 print(part.ratings)
# ---> 11 result = machine.process_part(part)
#      12 print(result)
#      13 if result == 'A':
#
# Cell In[2], line 55, in WorkflowMachine.process_part(self, part)
#      53 def process_part(self, part):
#      54     while self.state not in ['A', 'R']:
# ---> 55         self.process(part)
#      56     return self.state
#
# File c:\Users\Lilly\Documents\GitHub\advent-of-code\.venv\Lib\site-packages\transitions\core.py:402, in Event.trigger(self, model, *args, **kwargs)
#     397 func = partial(self._trigger, EventData(None, self, self.machine, model, args=args, kwargs=kwargs))
#     398 # pylint: disable=protected-access
#     399 # noinspection PyProtectedMember
#     400 # Machine._process should not be called somewhere else. That's why it should not be exposed
#     401 # to Machine users.
# --> 402 return self.machine._process(func)
#
# File c:\Users\Lilly\Documents\GitHub\advent-of-code\.venv\Lib\site-packages\transitions\core.py:1211, in Machine._process(self, trigger)
#    1208 if not self.has_queue:
#    1209     if not self._transition_queue:
#    1210         # if trigger raises an Error, it has to be handled by the Machine.process caller
# -> 1211         return trigger()
#    1212     raise MachineError("Attempt to process events synchronously while transition queue is not empty!")
#    1214 # process queued events
#
# File c:\Users\Lilly\Documents\GitHub\advent-of-code\.venv\Lib\site-packages\transitions\core.py:416, in Event._trigger(self, event_data)
#     414 try:
#     415     if self._is_valid_source(event_data.state):
# --> 416         self._process(event_data)
#     417 except Exception as err:  # pylint: disable=broad-except; Exception will be handled elsewhere
#     418     event_data.error = err
#
# File c:\Users\Lilly\Documents\GitHub\advent-of-code\.venv\Lib\site-packages\transitions\core.py:439, in Event._process(self, event_data)
#     437 for trans in self.transitions[event_data.state.name]:
#     438     event_data.transition = trans
# --> 439     if trans.execute(event_data):
#     440         event_data.result = True
#     441         break
#
# File c:\Users\Lilly\Documents\GitHub\advent-of-code\.venv\Lib\site-packages\transitions\core.py:277, in Transition.execute(self, event_data)
#     274 _LOGGER.debug("%sExecuted callback before transition.", event_data.machine.name)
#     276 if self.dest:  # if self.dest is None this is an internal transition with no actual state change
# --> 277     self._change_state(event_data)
#     279 event_data.machine.callbacks(itertools.chain(self.after, event_data.machine.after_state_change), event_data)
#     280 _LOGGER.debug("%sExecuted callback after transition.", event_data.machine.name)
#
# File c:\Users\Lilly\Documents\GitHub\advent-of-code\.venv\Lib\site-packages\transitions\core.py:285, in Transition._change_state(self, event_data)
#     283 def _change_state(self, event_data):
#     284     event_data.machine.get_state(self.source).exit(event_data)
# --> 285     event_data.machine.set_state(self.dest, event_data.model)
#     286     event_data.update(getattr(event_data.model, event_data.machine.model_attribute))
#     287     event_data.machine.get_state(self.dest).enter(event_data)
#
# File c:\Users\Lilly\Documents\GitHub\advent-of-code\.venv\Lib\site-packages\transitions\core.py:782, in Machine.set_state(self, state, model)
#     775 """
#     776     Set the current state.
#     777 Args:
#     778     state (str or Enum or State): value of state to be set
#     779     model (optional[object]): targeted model; if not set, all models will be set to 'state'
#     780 """
#     781 if not isinstance(state, State):
# --> 782     state = self.get_state(state)
#     783 models = self.models if model is None else listify(model)
#     785 for mod in models:
#
# File c:\Users\Lilly\Documents\GitHub\advent-of-code\.venv\Lib\site-packages\transitions\core.py:748, in Machine.get_state(self, state)
#     746     state = state.name
#     747 if state not in self.states:
# --> 748     raise ValueError("State '%s' is not a registered state." % state)
#     749 return self.states[state]
#
# ValueError: State '=qs' is not a registered state.
