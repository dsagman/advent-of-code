# %%
from hashlib import md5
from sys import exit

salt = 'abc'
i = 0
hashes = []
triplets = []
quintuplets = []
keys = []

def hash(input, stretching):
    if stretching > 0:
        return hash(md5(input.encode('ascii')).hexdigest(), stretching-1)
    else:
        return md5(input.encode('ascii')).hexdigest()

while i < 50000:
    hashes.append(hash(salt+str(i), 0))
    for c in range(30):
        char = hashes[i][c]
        if hashes[i][c:c+3] == char*3:
            triplets.append((i,char))
            # print('found triplet', char, i, len(triplets))
            if hashes[i][c:c+5] == char*5:
                quintuplets.append((i,char))
                # print('found quintuplet', char, i, len(quintuplets))                
            break
    i+=1

for triplet in triplets:
    if len([i for (i,char) in quintuplets if triplet[0] < i <= triplet[0]+1000 and char == triplet[1]]) > 0:
        keys.append(triplet)
        print('found key', triplet, len(keys))
        if len(keys) == 64:
            print('64th key', triplet)
            exit()
# Out:
# found key (39, 'e') 1
# found key (92, '9') 2
# found key (110, '9') 3
# found key (184, 'e') 4
# found key (291, '4') 5
# found key (314, '3') 6
# found key (343, '4') 7
# found key (385, '4') 8
# found key (459, '3') 9
# found key (461, '3') 10
# found key (489, '4') 11
# found key (771, '3') 12
# found key (781, '4') 13
# found key (887, '4') 14
# found key (955, '4') 15
# found key (1144, '4') 16
# found key (5742, 'd') 17
# found key (5781, 'd') 18
# found key (5783, 'd') 19
# found key (6016, 'd') 20
# found key (6093, 'd') 21
# found key (6219, 'd') 22
# found key (7833, '1') 23
# found key (7858, '0') 24
# found key (7918, '0') 25
# found key (7937, '0') 26
# found key (8042, '1') 27
# found key (8045, '1') 28
# found key (8183, '1') 29
# found key (8189, '1') 30
# found key (8205, '0') 31
# found key (8232, '1') 32
# found key (8375, '1') 33
# found key (8407, '0') 34
# found key (8431, '0') 35
# found key (8503, '0') 36
# found key (8517, '1') 37
# found key (8626, '0') 38
# found key (8672, '0') 39
# found key (8730, '0') 40
# found key (8811, '1') 41
# found key (9497, '1') 42
# found key (9536, '1') 43
# found key (13268, 'b') 44
# found key (13439, 'b') 45
# found key (13479, 'b') 46
# found key (13560, 'b') 47
# found key (13663, 'b') 48
# found key (15758, '7') 49
# found key (15883, '7') 50
# found key (16187, '7') 51
# found key (16342, '7') 52
# found key (16479, '7') 53
# found key (20087, 'a') 54
# found key (20371, 'a') 55
# found key (20582, 'a') 56
# found key (20635, 'a') 57
# found key (20669, 'a') 58
# found key (21908, 'c') 59
# found key (21927, 'c') 60
# found key (21978, 'c') 61
# found key (22023, 'c') 62
# found key (22193, 'c') 63
# found key (22728, 'c') 64
# 64th key (22728, 'c')
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit

# %%
from hashlib import md5
from sys import exit

# salt = 'abc'
salt = 'ihaygndm'
i = 0
hashes = []
triplets = []
quintuplets = []
keys = []

def hash(input, stretching):
    if stretching > 0:
        return hash(md5(input.encode('ascii')).hexdigest(), stretching-1)
    else:
        return md5(input.encode('ascii')).hexdigest()

while i < 50000:
    hashes.append(hash(salt+str(i), 2016))
    for c in range(30):
        char = hashes[i][c]
        if hashes[i][c:c+3] == char*3:
            triplets.append((i,char))
            # print('found triplet', char, i, len(triplets))
            if hashes[i][c:c+5] == char*5:
                quintuplets.append((i,char))
                # print('found quintuplet', char, i, len(quintuplets))                
            break
    i+=1

for triplet in triplets:
    if len([i for (i,char) in quintuplets if triplet[0] < i <= triplet[0]+1000 and char == triplet[1]]) > 0:
        keys.append(triplet)
        print('found key', triplet, len(keys))
        if len(keys) == 64:
            print('64th key', triplet)
            exit()
# Out:
# found key (10, 'e') 1
# found key (25, 'e') 2
# found key (1471, '5') 3
# found key (1596, '5') 4
# found key (1610, '5') 5
# found key (1715, '5') 6
# found key (1778, '5') 7
# found key (1951, '5') 8
# found key (1994, '5') 9
# found key (2023, '5') 10
# found key (2288, '5') 11
# found key (4249, '8') 12
# found key (4340, '8') 13
# found key (4352, '8') 14
# found key (4533, '8') 15
# found key (4829, '8') 16
# found key (4878, '8') 17
# found key (5014, '8') 18
# found key (5226, '2') 19
# found key (5803, '2') 20
# found key (6878, '1') 21
# found key (7087, '1') 22
# found key (7120, '1') 23
# found key (7137, '1') 24
# found key (7182, '1') 25
# found key (7229, '1') 26
# found key (7280, '1') 27
# found key (7317, '1') 28
# found key (7460, '1') 29
# found key (7841, '1') 30
# found key (8058, '6') 31
# found key (8277, '6') 32
# found key (8472, '6') 33
# found key (8473, '6') 34
# found key (8487, '6') 35
# found key (8550, '6') 36
# found key (8574, '6') 37
# found key (17372, 'c') 38
# found key (17438, 'c') 39
# found key (17506, 'c') 40
# found key (17737, 'c') 41
# found key (17768, 'c') 42
# found key (18105, 'c') 43
# found key (18175, 'c') 44
# found key (18210, 'c') 45
# found key (18302, 'c') 46
# found key (19212, '5') 47
# found key (19236, '5') 48
# found key (19270, '5') 49
# found key (19334, '5') 50
# found key (19346, '5') 51
# found key (19366, '6') 52
# found key (19369, '5') 53
# found key (19471, '5') 54
# found key (19498, '5') 55
# found key (19799, '6') 56
# found key (19880, '5') 57
# found key (19915, '6') 58
# found key (19947, '6') 59
# found key (19950, '6') 60
# found key (20212, '6') 61
# found key (22097, 'f') 62
# found key (22122, 'f') 63
# found key (22551, 'f') 64
# 64th key (22551, 'f')
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# /home/agman/Documents/GitHub/advent-of-code/.venv/lib/python3.13/site-packages/IPython/core/interactiveshell.py:3707: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
